-- %%
USE CATALOG workspace;

-- %%
CREATE TABLE IF NOT EXISTS getting_started.department
(
   deptcode   INT,
   deptname  STRING,
   location  STRING
);

-- %%
INSERT INTO getting_started.department VALUES
   (10, 'FINANCE', 'EDINBURGH'),
   (20, 'SOFTWARE', 'PADDINGTON');

-- %%
GRANT SELECT ON getting_started.department TO ``;
